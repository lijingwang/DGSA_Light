# %%
import numpy as np
from DGSA_light import DGSA_light
from gsa_pareto_plt import gsa_pareto_plt
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Step 1, input

# %%
# 1 input, model_parameters:  L x N_input  dimension
model_parameters = pd.read_csv('./tutorial_data/m_parameters.csv')

# %% [markdown]
# Step 2, output

# %%
# 2 output, model_responses: L x N_output dimension
model_responses = pd.read_csv('./tutorial_data/m_responses.csv')

# %% [markdown]
# Step 3 & 4, Clustering + DGSA

# %%
# Call DGSA
# 3 clusutering by K-medoids, Euclidean distance
# 4 DGSA: calculating sensitivities
dgsa_measures = DGSA_light(model_parameters.values, model_responses.values,model_parameters.columns)
# Out:
# 100%|██████████| 3000/3000 [00:32<00:00, 93.41it/s]

# %% [markdown]
# Visualization: the Pareto plot

# %%
gsa_pareto_plt(dgsa_measures)

# %%
c
